# %%
pip install psycopg2

# %%
# SQLAlchemy
from sqlalchemy import create_engine
import pandas as pd

# %%
postgresStr = ("postgresql://postgres:password@localhost:5432/project_dos")

# %%
engine = create_engine(postgresStr)
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/project_dos)

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM final_cleaned_data")

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#        0           1           2         3         4         5  \
# 0    AAL  2020-02-10  2020-03-09   28.7900   14.7500  -14.0400
# 1   AAPL  2020-02-10  2020-03-09  321.5500  266.1700  -55.3800
# 2   ABBV  2020-02-10  2020-03-09   94.7500   85.2700   -9.4800
# 3    ACB  2020-02-10  2020-03-09    1.5600    0.9490   -0.6110
# 4    AMD  2020-02-10  2020-03-09   52.2600   43.2700   -8.9900
# ..   ...         ...         ...       ...       ...       ...
# 95   WMT  2020-02-10  2020-03-09  115.2500  117.1600    1.9100
# 96  WORK  2020-02-10  2020-03-09   26.5400   24.8900   -1.6500
# 97   XOM  2020-02-10  2020-03-09   59.9600   41.8600  -18.1000
# 98    ZM  2020-02-10  2020-03-09   89.6700  113.7500   24.0800
# 99  ZNGA  2020-02-10  2020-03-09    6.7900    6.5300   -0.2600
#
#                           6            7                8
# 0   -0.48766932962834317471     220.0000   481176321.0000
# 1   -0.17222826932047893018    1036.0000   981499196.0000
# ...

# %%
df1 = df.rename(columns={0: "symbol", 1: "from_date", 2: "to_date", 3: "init_close", 4: "final_close",5: "net_change",6: "pct_change",7: "article_count",8: "ttl_vol"})

# %%
df1
# Out:
#    symbol   from_date     to_date init_close final_close net_change  \
# 0     AAL  2020-02-10  2020-03-09    28.7900     14.7500   -14.0400
# 1    AAPL  2020-02-10  2020-03-09   321.5500    266.1700   -55.3800
# 2    ABBV  2020-02-10  2020-03-09    94.7500     85.2700    -9.4800
# 3     ACB  2020-02-10  2020-03-09     1.5600      0.9490    -0.6110
# 4     AMD  2020-02-10  2020-03-09    52.2600     43.2700    -8.9900
# ..    ...         ...         ...        ...         ...        ...
# 95    WMT  2020-02-10  2020-03-09   115.2500    117.1600     1.9100
# 96   WORK  2020-02-10  2020-03-09    26.5400     24.8900    -1.6500
# 97    XOM  2020-02-10  2020-03-09    59.9600     41.8600   -18.1000
# 98     ZM  2020-02-10  2020-03-09    89.6700    113.7500    24.0800
# 99   ZNGA  2020-02-10  2020-03-09     6.7900      6.5300    -0.2600
#
#                  pct_change article_count          ttl_vol
# 0   -0.48766932962834317471      220.0000   481176321.0000
# ...

# %%
df1.to_csv("final_cleaned_data.csv", index = False, header = True)
